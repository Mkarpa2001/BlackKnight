# %% [markdown]
# # TITANIC SURVIVAL PREDICTION

# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'][df.Pclass==1]=df['Age'][df.Pclass==1].fillna(38)
df['Age'][df.Pclass==3]=df['Age'][df.Pclass==3].fillna(25)
df['Age'][df.Pclass==2]=df['Age'][df.Pclass==2].fillna(29)
# Out:
# <ipython-input-11-2e589c5859f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][df.Pclass==1]=df['Age'][df.Pclass==1].fillna(38)
# <ipython-input-11-2e589c5859f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][df.Pclass==3]=df['Age'][df.Pclass==3].fillna(25)
# <ipython-input-11-2e589c5859f1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dummies=pd.get_dummies(df.Embarked,drop_first=True)

# %%
df=pd.concat([df,dummies],axis='columns')

# %%
dummies=pd.get_dummies(df.Sex,drop_first=True)

# %%
df=pd.concat([df,dummies],axis='columns')

# %%
x=df.drop(['PassengerId','Survived','Name','Ticket','Embarked','Cabin'],axis='columns')

# %%
x.drop(['Sex'],axis='columns',inplace=True)
# Out:
# e:\python\lib\site-packages\pandas\core\frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
pd.crosstab(df.Embarked,df.Survived).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Embarked'>

# %%
y=df.Survived

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Age     891 non-null    float64
#  2   SibSp   891 non-null    int64
#  3   Parch   891 non-null    int64
#  4   Fare    891 non-null    float64
#  5   Q       891 non-null    uint8
#  6   S       891 non-null    uint8
#  7   male    891 non-null    uint8
#  8   male    891 non-null    uint8
# dtypes: float64(2), int64(3), uint8(4)
# memory usage: 38.4 KB

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier(criterion='entropy')
model.fit(x,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Age     891 non-null    float64
#  2   SibSp   891 non-null    int64
#  3   Parch   891 non-null    int64
#  4   Fare    891 non-null    float64
#  5   Q       891 non-null    uint8
#  6   S       891 non-null    uint8
#  7   male    891 non-null    uint8
# dtypes: float64(2), int64(3), uint8(3)
# memory usage: 37.5 KB

# %%
model.score(x_test,y_test)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
model.predict(x_test)

# %%
model.score(x,y)
# Out:
# 0.9820426487093153

# %%
d=pd.read_csv("test.csv")

# %%
d
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
d.groupby('Pclass').mean()
# Out:
#         PassengerId        Age     SibSp     Parch       Fare
# Pclass
# 1       1098.224299  40.918367  0.476636  0.383178  94.280297
# 2       1117.935484  28.777500  0.376344  0.344086  22.202104
# 3       1094.178899  24.027945  0.463303  0.417431  12.459678

# %%
d['Age'][d.Pclass==1]=d['Age'][d.Pclass==1].fillna(40)
d['Age'][d.Pclass==3]=d['Age'][d.Pclass==3].fillna(24)
d['Age'][d.Pclass==2]=d['Age'][d.Pclass==2].fillna(28)
# Out:
# <ipython-input-37-7c1a8e924a35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Age'][d.Pclass==1]=d['Age'][d.Pclass==1].fillna(40)
# <ipython-input-37-7c1a8e924a35>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Age'][d.Pclass==3]=d['Age'][d.Pclass==3].fillna(24)
# <ipython-input-37-7c1a8e924a35>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Age'][d.Pclass==2]=d['Age'][d.Pclass==2].fillna(28)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
dummies=pd.get_dummies(d.Sex,drop_first=True)

# %%
d=pd.concat([d,dummies],axis='columns')

# %%
dummies=pd.get_dummies(d.Embarked,drop_first=True)

# %%
d=pd.concat([d,dummies],axis='columns')

# %%
d
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
x1=d.drop(['PassengerId','Name','Sex','Ticket','Cabin','Embarked'],axis='columns')

# %%
d
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
x1
# Out:
#      Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 0         3  34.5      0      0    7.8292     1  1  0
# 1         3  47.0      1      0    7.0000     0  0  1
# 2         2  62.0      0      0    9.6875     1  1  0
# 3         3  27.0      0      0    8.6625     1  0  1
# 4         3  22.0      1      1   12.2875     0  0  1
# ..      ...   ...    ...    ...       ...   ... .. ..
# 413       3  24.0      0      0    8.0500     1  0  1
# 414       1  39.0      0      0  108.9000     0  0  0
# 415       3  38.5      0      0    7.2500     1  0  1
# 416       3  24.0      0      0    8.0500     1  0  1
# 417       3  24.0      1      1   22.3583     1  0  0
#
# [418 rows x 8 columns]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  418 non-null    int64
#  1   Age     418 non-null    float64
#  2   SibSp   418 non-null    int64
#  3   Parch   418 non-null    int64
#  4   Fare    417 non-null    float64
#  5   male    418 non-null    uint8
#  6   Q       418 non-null    uint8
#  7   S       418 non-null    uint8
# dtypes: float64(2), int64(3), uint8(3)
# memory usage: 17.7 KB

# %%
y_hats=model.predict(x1)
train=pd.DataFrame(y_hats,dtype=int)

# %%
len(x1)
# Out:
# 417

# %%
x1.dropna(inplace=True)

# %%
train
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# ..  ..
# 412  0
# 413  1
# 414  0
# 415  0
# 416  1
#
# [417 rows x 1 columns]

# %%
submit=pd.DataFrame(d.PassengerId,columns=("PassengerId","Survived"))

# %%
submit=pd.concat([d.PassengerId,train],axis='columns',ignore_index=True)

# %%
submit
# Out:
#         0    1
# 0     892  0.0
# 1     893  0.0
# 2     894  0.0
# 3     895  1.0
# 4     896  0.0
# ..    ...  ...
# 413  1305  1.0
# 414  1306  0.0
# 415  1307  0.0
# 416  1308  1.0
# 417  1309  NaN
#
# [418 rows x 2 columns]
